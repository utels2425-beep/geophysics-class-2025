# %%
import pygmt
fig = pygmt.Figure()
fig.coast(region=[119, 123, 21.5, 25.5], projection="M12c", shorelines=True, frame=True)
fig.plot(x=[121.6], y=[24.0], style="c0.3c", color="red")
fig.show()
# Out:
# /tmp/ipykernel_8546/1109182496.py:4: FutureWarning: The 'color' parameter has been deprecated since v0.8.0 and will be removed in v0.12.0. Please use 'fill' instead.
#   fig.plot(x=[121.6], y=[24.0], style="c0.3c", color="red")
